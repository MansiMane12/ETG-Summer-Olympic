# %% [markdown]
# # Summer Olympics Data Analysis Assignment

# %%
import pandas as pd

# %%
df=pd.read_csv("summer.csv")

# %%
df
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# 5      1896  Athens   Aquatics             Swimming
# 6      1896  Athens   Aquatics             Swimming
# 7      1896  Athens   Aquatics             Swimming
# 8      1896  Athens   Aquatics             Swimming
# 9      1896  Athens   Aquatics             Swimming
# 10     1896  Athens   Aquatics             Swimming
# 11     1896  Athens  Athletics            Athletics
# 12     1896  Athens  Athletics            Athletics
# 13     1896  Athens  Athletics            Athletics
# 14     1896  Athens  Athletics            Athletics
# 15     1896  Athens  Athletics            Athletics
# 16     1896  Athens  Athletics            Athletics
# ...

# %%
df.isnull().sum()
# Out:
# Year          0
# City          0
# Sport         0
# Discipline    0
# Athlete       0
# Country       4
# Gender        0
# Event         0
# Medal         0
# dtype: int64

# %% [markdown]
# ### 1. In how many cities Summer Olympics is held so far?

# %%
df["City"].unique()
# Out:
# array(['Athens', 'Paris', 'St Louis', 'London', 'Stockholm', 'Antwerp',
#        'Amsterdam', 'Los Angeles', 'Berlin', 'Helsinki',
#        'Melbourne / Stockholm', 'Rome', 'Tokyo', 'Mexico', 'Munich',
#        'Montreal', 'Moscow', 'Seoul', 'Barcelona', 'Atlanta', 'Sydney',
#        'Beijing'], dtype=object)

# %%
len(df["City"].unique())
# Out:
# 22

# %% [markdown]
# ### 2. Which sport is having most number of Gold Medals so far? (Top 5)

# %%
data= most_gold_medals=df.Sport[df.Medal=='Gold'].value_counts().head()
most_gold_medals
# Out:
# Aquatics      1421
# Athletics     1215
# Rowing         890
# Gymnastics     820
# Fencing        552
# Name: Sport, dtype: int64

# %%
data
# Out:
# Aquatics      1421
# Athletics     1215
# Rowing         890
# Gymnastics     820
# Fencing        552
# Name: Sport, dtype: int64

# %%
data.plot(x='sport',y='Medal',kind='bar',color="purple")

# %% [markdown]
# ### 3. Which sport is having most number of medals so far? (Top 5)

# %%
df.groupby('Sport').count()
# Out:
#                    Year  City  Discipline  Athlete  Country  Gender  Event  \
# Sport
# Aquatics           4170  4170        4170     4170     4170    4170   4170
# Archery             329   329         329      329      329     329    329
# Athletics          3638  3638        3638     3638     3637    3638   3638
# Badminton           144   144         144      144      144     144    144
# Baseball            335   335         335      335      335     335    335
# Basketball         1012  1012        1012     1012     1012    1012   1012
# Basque Pelota         4     4           4        4        4       4      4
# Boxing              894   894         894      894      894     894    894
# Canoe                81    81          81       81       81      81     81
# Canoe / Kayak      1002  1002        1002     1002     1002    1002   1002
# Cricket              24    24          24       24       24      24     24
# ...

# %%
df.groupby('Sport').count()['Medal'].sort_values(ascending=False).head()
# Out:
# Sport
# Aquatics      4170
# Athletics     3638
# Rowing        2667
# Gymnastics    2307
# Fencing       1613
# Name: Medal, dtype: int64

# %%
df.groupby('Sport').count()['Medal'].sort_values(ascending=False).head().plot(x='sport',y='Medal',kind='bar',color="green")

# %% [markdown]
# ### 4. Which player has won most number of medals? (Top 5)

# %%
df.groupby('Athlete').count()['Medal'].sort_values(ascending=False).head()
# Out:
# Athlete
# PHELPS, Michael         22
# LATYNINA, Larisa        18
# ANDRIANOV, Nikolay      15
# MANGIAROTTI, Edoardo    13
# SHAKHLIN, Boris         13
# Name: Medal, dtype: int64

# %%
df.groupby('Athlete').count()['Medal'].sort_values(ascending=False).head().plot(x='Athlete',y='Medal',kind='bar',color="orange")

# %% [markdown]
# ### 5. Which player has won most number Gold Medals of medals? (Top 5)

# %%
player_with_most_gold_medals=df.Athlete[df.Medal == 'Gold'].value_counts()
player_with_most_gold_medals
# Out:
# PHELPS, Michael                    18
# LEWIS, Carl                         9
# NURMI, Paavo                        9
# LATYNINA, Larisa                    9
# SPITZ, Mark                         9
# EWRY, Ray                           8
# BIONDI, Matthew                     8
# FISCHER, Birgit                     8
# KATO, Sawao                         8
# THOMPSON, Jenny                     8
# GEREVICH, Aladar                    7
# CASLAVSKA, Vera                     7
# SHAKHLIN, Boris                     7
# ANDRIANOV, Nikolay                  7
# CHUKARIN, Viktor Ivanovich          7
# HOY, Chris                          6
# KLIMKE, Reiner                      6
# FREDRIKSSON, Gert                   6
# KOVACS, Pal Adam                    6
# NADI, Nedo                          6
# VAN INNIS, Hubert                   6
# OTTO, Kristin                       6
# BOLT, Usain                         6
# SCHERBO, Vitaly                     6
# VEZZALI, Valentina                  6
# ...

# %%
player_with_most_gold_medals.head()
# Out:
# PHELPS, Michael     18
# LEWIS, Carl          9
# NURMI, Paavo         9
# LATYNINA, Larisa     9
# SPITZ, Mark          9
# Name: Athlete, dtype: int64

# %%
player_with_most_gold_medals.head().plot(x='Athlete',y='Medal',kind='bar',color="black")

# %% [markdown]
# ### 6. In which year India won first Gold Medal in Summer Olympics?

# %%
df_gold=df[df['Medal']=='Gold']

df_gold['Country'].unique()
# Out:
# array(['HUN', 'GRE', 'AUT', 'USA', 'AUS', 'FRA', 'GER', 'SUI', 'ZZX',
#        'GBR', 'DEN', 'BEL', 'CAN', 'ESP', 'ITA', 'CUB', 'SWE', 'RSA',
#        'ANZ', 'NOR', 'RU1', 'FIN', 'NED', 'BRA', 'EST', 'URU', 'YUG',
#        'TCH', 'ARG', 'JPN', 'POL', 'IRL', 'NZL', 'IND', 'EGY', 'TUR',
#        'JAM', 'MEX', 'PER', 'LUX', 'URS', 'ROU', 'EUA', 'IRI', 'BUL',
#        'ETH', 'PAK', 'BAH', 'GDR', 'KEN', 'TUN', 'FRG', 'VEN', 'UGA',
#        'PRK', 'TRI', 'KOR', 'ZIM', 'CHN', 'MAR', 'POR', 'SUR', 'EUN',
#        'ALG', 'LTU', 'INA', 'RUS', 'CRC', 'ECU', 'BDI', 'SYR', 'CZE',
#        'NGR', 'UKR', 'THA', 'KAZ', 'SVK', 'CRO', 'BLR', 'HKG', 'ARM',
#        'MOZ', 'UZB', 'CMR', 'LAT', 'SLO', 'AZE', 'COL', 'DOM', 'GEO',
#        'ISR', 'UAE', 'TPE', 'CHI', 'PAN', 'MGL', nan, 'GRN', 'TTO', 'SRB'],
#       dtype=object)

# %%
year_asc=df_gold.sort_values(['Year'],ascending=True)

india_first_gold=year_asc[year_asc['Country']=='IND'].iloc[0]

print("The year India won its first Gold Medal in Summer Olympics is ",india_first_gold['Year'])
# Out:
# ('The year India won its first Gold Medal in Summer Olympics is ', 1928)

# %% [markdown]
# ### 7. Which event is most popular in terms on number of players? (Top 5)

# %%
most_popular_events=df[(df.Event != 0) & (df.Athlete != 0 )][['Event','Athlete']]
most_popular_events=most_popular_events.groupby('Event').count().reset_index()
most_popular_events=most_popular_events.sort_values(by='Athlete',ascending=False).head()
most_popular_events
# Out:
#                 Event  Athlete
# 477          Football     1497
# 489            Hockey     1422
# 614  Team Competition     1147
# 403        Basketball     1012
# 483          Handball      973

# %%
most_popular_events=df[(df.Event != 0) & (df.Athlete != 0 )][['Event','Athlete']]
most_popular_events=most_popular_events.groupby('Event').count().reset_index()
most_popular_events=most_popular_events.sort_values(by='Athlete',ascending=False).head().plot(x='Event',y='Athlete',kind='bar',color="red")

# %% [markdown]
# ### 8. Which sport is having most female Gold Medalists? (Top 5)

# %%
df['Gender'].unique()
# Out:
# array(['Men', 'Women'], dtype=object)

# %%
df_gold=df[df['Medal']=='Gold']

# %%
df_gold_female=df_gold[df_gold['Gender']=='Women']

# %%
df_gold_female
# Out:
#        Year       City          Sport           Discipline  \
# 417    1900      Paris           Golf                 Golf
# 641    1900      Paris         Tennis               Tennis
# 649    1900      Paris         Tennis               Tennis
# 710    1904   St Louis        Archery              Archery
# 713    1904   St Louis        Archery              Archery
# 730    1904   St Louis        Archery              Archery
# 731    1904   St Louis        Archery              Archery
# 732    1904   St Louis        Archery              Archery
# 733    1904   St Louis        Archery              Archery
# 1185   1908     London        Archery              Archery
# 1843   1908     London        Skating       Figure skating
# 1849   1908     London        Skating       Figure skating
# 1870   1908     London         Tennis               Tennis
# 1876   1908     London         Tennis               Tennis
# 1941   1912  Stockholm       Aquatics               Diving
# ...

# %%
df_gold_female.groupby('Sport').count()['Gender'].sort_values(ascending=False).head().plot(x='Female',y='Gold',kind='bar')
